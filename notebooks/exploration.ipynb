# %%
from src.evaluate import evaluate_models
from src.analysis import compare_predictions, compare_local_explanation_to_shap

# %%
evaluate_models()
# Out:
# (1309, 13)
# --- Neural Network ---
#               precision    recall  f1-score   support
#
#     Died (0)       0.85      0.91      0.88       162
# Survived (1)       0.83      0.75      0.79       100
#
#     accuracy                           0.85       262
#    macro avg       0.84      0.83      0.83       262
# weighted avg       0.85      0.85      0.85       262
#
# --- Logistic Regression ---
#               precision    recall  f1-score   support
#
#     Died (0)       0.83      0.86      0.85       162
# Survived (1)       0.76      0.71      0.74       100
#
#     accuracy                           0.81       262
#    macro avg       0.80      0.79      0.79       262
# weighted avg       0.80      0.81      0.80       262
#
# --- Decision Tree ---
#               precision    recall  f1-score   support
#
#     Died (0)       0.85      0.90      0.87       162
# Survived (1)       0.81      0.74      0.77       100
#
# ...

# %%
compare_predictions(sample_idx=14)

# %%
compare_local_explanation_to_shap(sample_idx=14)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...
